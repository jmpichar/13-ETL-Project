# %%
import pandas as pd
#import numpy as np
#from bs4 import BeautifulSoup4 as bs

# %%
deaths_2015_df = pd.read_csv('./resources/2015-death-data.csv')

# %%
#CDC data on Morphine Milligram equivalents by county. Based on raw data from 
#QuintilesIMS Transactional Data Warehouse
#https://data.world/jmpichar/opioid-prescriptions/workspace/file?agentid=associatedpress&datasetid=opioid-prescriptions-2010-2015&filename=Opioid_prescription_amounts.csv
#
opioids_2010_2015_rx_df = pd.read_csv('./resources/Opioid_prescription_amounts.csv')

# %%
# mulltiple cause of death data on CDC Wonder
#https://data.world/health/opioid-overdose-deaths
mcd_1999_2014_df = pd.read_csv('./resources/multiple_cause_death_1999-2014.csv')

# %%
mcd_1999_2014_df.head(5)
# Out:
#      State  Year Deaths  Population Crude Rate  \
# 0  Alabama  1999     39     4430141        0.9
# 1  Alabama  2000     46     4447100          1
# 2  Alabama  2001     67     4467634        1.5
# 3  Alabama  2002     75     4480089        1.7
# 4  Alabama  2003     54     4503491        1.2
#
#   Crude Rate Lower 95% Confidence Interval  \
# 0                                      0.6
# 1                                      0.8
# 2                                      1.2
# 3                                      1.3
# 4                                      0.9
#
#   Crude Rate Upper 95% Confidence Interval  \
# 0                                      1.2
# 1                                      1.4
# 2                                      1.9
# 3                                      2.1
# 4                                      1.6
#
#    Prescriptions Dispensed by US Retailers in that year (millions)
# 0                                                116
# ...

# %%
mask = (mcd_1999_2014_df['Year'] == 2000) |(mcd_1999_2014_df['Year'] == 2014)

# %%
mcd_1999_2014_df[mask]
# Out:
#                     State  Year      Deaths  Population  Crude Rate  \
# 1                 Alabama  2000          46     4447100           1
# 15                Alabama  2014         282     4849377         5.8
# 17                 Alaska  2000          27      626932         4.3
# 31                 Alaska  2014          79      736732        10.7
# 33                Arizona  2000         249     5130632         4.9
# 47                Arizona  2014         616     6731484         9.2
# 49               Arkansas  2000          20     2673400         0.7
# 63               Arkansas  2014         179     2966369           6
# 65             California  2000        1105    33871648         3.3
# 79             California  2014        2159    38802500         5.6
# 81               Colorado  2000         184     4301261         4.3
# 95               Colorado  2014         532     5355866         9.9
# 97            Connecticut  2000         173     3405565         5.1
# ...

# %%
mcd_1999_2014_df.columns
# Out:
# Index(['State', 'Year', 'Deaths', 'Population', 'Crude Rate',
#        'Crude Rate Lower 95% Confidence Interval',
#        'Crude Rate Upper 95% Confidence Interval',
#        'Prescriptions Dispensed by US Retailers in that year (millions)'],
#       dtype='object')

# %%
rx_by_year = mcd_1999_2014_df.groupby(['State','Year'])

# %%
rx_by_year.sum()
# Out:
#                 Population  \
# State     Year
# Alabama   1999     4430141
#           2000     4447100
#           2001     4467634
#           2002     4480089
#           2003     4503491
#           2004     4530729
#           2005     4569805
#           2006     4628981
#           2007     4672840
#           2008     4718206
#           2009     4757938
#           2010     4779736
#           2011     4802740
#           2012     4822023
#           2013     4833722
#           2014     4849377
# Alaska    1999      624779
#           2000      626932
#           2001      633714
#           2002      642337
#           2003      648414
#           2004      659286
#           2005      666946
#           2006      675302
#           2007      680300
#           2008      687455
#           2009      698895
#           2010      710231
#           2011      722718
#           2012      731449
# ...                    ...
# Wisconsin 2001     5406835
# ...

# %%
deaths_2015_df.head(3)
# Out:
#   State         Range  Rate Number  Unnamed: 4  Unnamed: 5  Unnamed: 6  \
# 0    AL  13.6 to 16.0  15.7    736         NaN         NaN         NaN
# 1    AK  13.6 to 16.0  16.0    122         NaN         NaN         NaN
# 2    AZ  18.6 to 21.0  19.0  1,274         NaN         NaN         NaN
#
#    Unnamed: 7
# 0         NaN
# 1         NaN
# 2         NaN

# %%
deaths_2015_df_mod = deaths_2015_df[['State', 'Range', 'Rate', 'Number']]

# %%
deaths_2015_df_mod.head(3)
# Out:
#   State         Range  Rate Number
# 0    AL  13.6 to 16.0  15.7    736
# 1    AK  13.6 to 16.0  16.0    122
# 2    AZ  18.6 to 21.0  19.0  1,274

# %%
opioids_2010_2015_rx_df.tail()
# Out:
#        FIPS State    County  MME_PerCap_2010  MME_PerCap_2015  Quartile_2015  \
# 3138  56039    WY     TETON            406.3            387.8            1.0
# 3139  56005    WY  CAMPBELL            581.7            384.7            1.0
# 3140  56015    WY    GOSHEN            601.4            375.4            1.0
# 3141  56011    WY     CROOK            210.7             11.2            1.0
# 3142  56027    WY  NIOBRARA              NaN              5.7            1.0
#
#      2010-2015_Change
# 3138           Stable
# 3139        Decreased
# 3140        Decreased
# 3141        Decreased
# 3142              NaN

# %%
states = opioids_2010_2015_rx_df.groupby(['State'])

# %%
states.mean()
# Out:
#                FIPS  MME_PerCap_2010  MME_PerCap_2015  Quartile_2015
# State
# AK      2153.517241       740.000000       553.183333       2.083333
# AL      1067.000000       935.525758       944.068657       2.880597
# AR      5075.000000       917.344776       825.583784       2.837838
# AZ      4013.866667      1064.942857       899.720000       2.933333
# CA      6058.000000      1063.996429       834.973684       2.631579
# CO      8062.234375       740.225490       609.546296       2.166667
# CT      9008.000000       736.300000       677.662500       2.625000
# DC     11001.000000       240.300000       205.900000       1.000000
# DE     10003.000000      1547.533333      1062.833333       3.666667
# FL     12067.910448      1244.433333       771.413433       2.776119
# GA     13161.490566       857.376692       736.761184       2.513158
# HI     15005.000000       966.350000       610.025000       2.250000
# ...

# %%
opioids_2010_2015_rx_df.head(3)
# Out:
#    FIPS State          County  MME_PerCap_2010  MME_PerCap_2015  \
# 0  2050    AK          BETHEL              NaN              NaN
# 1  2068    AK          DENALI              NaN              NaN
# 2  2013    AK  ALEUTIANS EAST              NaN              NaN
#
#    Quartile_2015 2010-2015_Change
# 0            NaN              NaN
# 1            NaN              NaN
# 2            NaN              NaN

# %%
opioids_2010_2015_rx_df.columns
# Out:
# Index(['FIPS', 'State', 'County', 'MME_PerCap_2010', 'MME_PerCap_2015',
#        'Quartile_2015', '2010-2015_Change'],
#       dtype='object')

# %%
#opioids_rx_df.drop(columns =['MME_PerCap_2010'],axis=1, inplace=True)

# %%
# drop 2010 data
# rename columns
